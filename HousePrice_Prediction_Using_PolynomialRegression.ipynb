# %%
#importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
myData=pd.read_csv('Housing_Price.csv')
myData
# Out:
#       sq_ft      Price
# 0    1307.0  3001959.0
# 1    1365.0  3167670.0
# 2    1251.0  2938785.0
# 3    1365.0  3294968.0
# 4    1374.0  3229588.0
# 5    1247.0  2938168.0
# 6    1373.0  3128903.0
# 7    1364.0  3208520.0
# 8    1297.0  3001333.0
# 9    1291.0  3001253.0
# 10   1361.0  3149302.0
# 11   1210.0  2931143.0
# 12   1365.0  3099031.0
# 13   1261.0  2987722.0
# 14   1061.0   141149.0
# 15   1382.0  3124828.0
# 16   1494.0  6212883.0
# 17   1354.0  3141785.0
# 18   1257.0  2996548.0
# 19   1497.0  5440332.0
# 20   1123.0  1778374.0
# 21   1231.0  2957902.0
# 22   1233.0  2932934.0
# 23   1263.0  2992094.0
# 24   1298.0  2999955.0
# 25   1346.0  3054407.0
# 26   1494.0  5599860.0
# 27   1408.0  3693809.0
# 28   1166.0  2561629.0
# 29   1082.0   229861.0
# ..      ...        ...
# 270  1269.0  3000141.0
# 271  1202.0  2855695.0
# 272  1253.0  2991962.0
# 273  1372.0  3044918.0
# 274  1302.0  3012434.0
# 275  1177.0  2527565.0
# 276  1387.0  3225612.0
# 277  1459.0  4691270.0
# ...

# %%
x=myData.iloc[:,0:1].values
x
# Out:
# array([[1307.],
#        [1365.],
#        [1251.],
#        [1365.],
#        [1374.],
#        [1247.],
#        [1373.],
#        [1364.],
#        [1297.],
#        [1291.],
#        [1361.],
#        [1210.],
#        [1365.],
#        [1261.],
#        [1061.],
#        [1382.],
#        [1494.],
#        [1354.],
#        [1257.],
#        [1497.],
#        [1123.],
#        [1231.],
#        [1233.],
#        [1263.],
#        [1298.],
#        [1346.],
#        [1494.],
#        [1408.],
#        [1166.],
#        [1082.],
#        [1421.],
#        [1182.],
#        [1207.],
#        [1294.],
#        [1324.],
#        [1269.],
#        [1136.],
#        [1358.],
#        [1376.],
#        [1282.],
#        [1296.],
#        [1233.],
#        [1419.],
#        [1363.],
#        [1181.],
#        [1321.],
#        [1343.],
#        [1445.],
#        [1333.],
#        [1270.],
#        [1344.],
#        [1260.],
#        [1288.],
#        [1272.],
#        [1348.],
# ...

# %%
y=myData.iloc[:,1].values
y
# Out:
# array([ 3001959.,  3167670.,  2938785.,  3294968.,  3229588.,  2938168.,
#         3128903.,  3208520.,  3001333.,  3001253.,  3149302.,  2931143.,
#         3099031.,  2987722.,   141149.,  3124828.,  6212883.,  3141785.,
#         2996548.,  5440332.,  1778374.,  2957902.,  2932934.,  2992094.,
#         2999955.,  3054407.,  5599860.,  3693809.,  2561629.,   229861.,
#         3702113.,  2597361.,  2802171.,  2999387.,  3006076.,  3000020.,
#         2246385.,  3102434.,  3275151.,  2997309.,  3000571.,  2972128.,
#         3568078.,  3101443.,  2611753.,  3004709.,  3048899.,  4098949.,
#         3007657.,  2958706.,  3102734.,  2999822.,  2999803.,  2999510.,
#         3157279.,  7664217.,  2952233.,  3000000.,  3005629.,  4128179.,
#         3013509.,  3579830.,  3111511.,  3456294.,  3141039.,  3000179.,
#         3000200.,  3409828.,  3000050.,  3189291.,  2991999.,  3183541.,
#         2992677.,  3483938.,  3322576.,  2921450.,  3010748.,  3703804.,
# ...

# %%
plt.scatter(x,y,color='red')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
createmyModel=LinearRegression()
createmyModel.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
plt.scatter(x,y,color='b')
plt.plot(x,createmyModel.predict(x),color='r')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
createpolyModel=PolynomialFeatures(degree=3)
x_poly=createpolyModel.fit_transform(x)
x_poly
# Out:
# array([[1.00000000e+00, 1.30700000e+03, 1.70824900e+06, 2.23268144e+09],
#        [1.00000000e+00, 1.36500000e+03, 1.86322500e+06, 2.54330212e+09],
#        [1.00000000e+00, 1.25100000e+03, 1.56500100e+06, 1.95781625e+09],
#        ...,
#        [1.00000000e+00, 1.35600000e+03, 1.83873600e+06, 2.49332602e+09],
#        [1.00000000e+00, 1.27000000e+03, 1.61290000e+06, 2.04838300e+09],
#        [1.00000000e+00, 1.16800000e+03, 1.36422400e+06, 1.59341363e+09]])

# %%
creatModelWithPoly=LinearRegression()
creatModelWithPoly.fit(x_poly,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
plt.scatter(x,y,color='blue')
plt.scatter(x,creatModelWithPoly.predict(x_poly),color='r')
plt.show()

# %%
creatModelWithPoly.score(x_poly,y)
# Out:
# 0.9751064094292466
